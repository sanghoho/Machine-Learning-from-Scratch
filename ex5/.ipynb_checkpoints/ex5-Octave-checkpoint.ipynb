% %% [markdown]
% # Octave Programming Assignment:
%
% ## Regularized Linear Regression and Bias-Variance
%
% ## 2020년 08월 30일 안상호
%
% ---

% %%
% Load Training Data
fprintf('Loading and Visualizing Data ...\n')

% Load from ex5data1: 
% You will have X, y, Xval, yval, Xtest, ytest in your environment
load ('ex5data1.mat');

% m = Number of examples
m = size(X, 1)
% Out:
% Loading and Visualizing Data ...
% m =  12

% %% [markdown]
% ---
%
% # 1. Regularized Linear Regression
%
% > predict the amount of water flowing out of a dam using the change of water level in a reservoir
%
% 모델을 진단하기 전에, Regularization을 적용한 Linear Regression에 대해서 복습해본다.
%
% ## 1.1. Visualizing the dataset

% %%
% Plot training data
plot(X, y, 'rx', 'MarkerSize', 10, 'LineWidth', 1.5);
xlabel('Change in water level (x)');
ylabel('Water flowing out of the dam (y)');

% %%
plot(Xval, yval, 'rx', 'MarkerSize', 10, 'LineWidth', 1.5);

% %%
plot(Xtest, ytest, 'rx', 'MarkerSize', 10, 'LineWidth', 1.5);

% %% [markdown]
% ## 1.2. Regularized linear regression cost function
%
% `linearRegCostFunction.m`
%
% $$J(\theta) = \dfrac{1}{2m} \bigg( \sum_{i=1}^{m}\left( h_{\theta}(x^{(i)}) - y^{(i)} \right)^2 \bigg) + \dfrac{\lambda}{2m} \bigg( \sum_{j=1}^{n} \theta_j^{2} \bigg) $$
%
% - 항상 $\theta_0$는 페널티를 가하지 않는다는 점에 유의하도록 한다.

% %%
theta = [1 ; 1];

% %%
(1 / (2 *m)) * sum(theta(2:2) .^ 2)
% Out:
% ans =  0.041667

% %%
(1 / (2*m)) * sum(([ones(m, 1) X] * theta - y) .^ 2)
% Out:
% ans =  303.95

% %%
J = linearRegCostFunction([ones(m, 1) X], y, theta, 1);

fprintf(['Cost at theta = [1 ; 1]: %f '...
         '\n(this value should be about 303.993192)\n'], J);
% Out:
% Cost at theta = [1 ; 1]: 303.993192
% (this value should be about 303.993192)

% %% [markdown]
% ## 1.3. Regularized linear regression gradient
%
% $$
% \begin{align}
% &\dfrac{\partial{J(\theta)}}{\partial \theta_0} = \dfrac{1}{m} \sum_{i=1}^{m} \left( h_{\theta}(x^{(i)}) - y^{(i)} \right)x_j^{(i)} & \text{for} \ j = 0 \\
% &\dfrac{\partial{J(\theta)}}{\partial \theta_j} = \bigg(\dfrac{1}{m} \sum_{i=1}^{m} \left( h_{\theta}(x^{(i)}) - y^{(i)} \right)x_j^{(i)} \bigg) + \dfrac{\lambda}{m}\theta_j &\text{for} \ j \geq 1
% \end{align}
% $$

% %%
theta = [1 ; 1];

% %%
grad_reg = (lambda / m) * theta;
grad_reg(1) = 0;

grad = (1 / m) * X' * (h - y) + grad_reg;
% Out:
% error: 'lambda' undefined near line 1 column 13
% error: 'h' undefined near line 1 column 24

% %%
[ones(m, 1) X]' * ([ones(m, 1) X] * theta - y)
% Out:
% ans =
%
%    -183.64
%    7178.01

% %%
[J, grad] = linearRegCostFunction([ones(m, 1) X], y, theta, 1);

fprintf(['Gradient at theta = [1 ; 1]:  [%f; %f] '...
         '\n(this value should be about [-15.303016; 598.250744])\n'], ...
         grad(1), grad(2));
% Out:
% Gradient at theta = [1 ; 1]:  [-15.303016; 598.250744]
% (this value should be about [-15.303016; 598.250744])

% %% [markdown]
% ## 1.4. Fitting linear regression

% %%
%% =========== Part 4: Train Linear Regression =============
%  Once you have implemented the cost and gradient correctly, the
%  trainLinearReg function will use your cost function to train 
%  regularized linear regression.
% 
%  Write Up Note: The data is non-linear, so this will not give a great 
%                 fit.
%

%  Train linear regression with lambda = 0
lambda = 0;
[theta] = trainLinearReg([ones(m, 1) X], y, lambda);

%  Plot fit over the data
plot(X, y, 'rx', 'MarkerSize', 10, 'LineWidth', 1.5);
xlabel('Change in water level (x)');
ylabel('Water flowing out of the dam (y)');
hold on;
plot(X, [ones(m, 1) X]*theta, '--', 'LineWidth', 2)
hold off;
% Out:
% Iteration     3 | Cost: 2.237391e+01

% %% [markdown]
% ---
%
% # 2. Bias-variance
%
% 머신러닝에서 bias-variance tradeoff에 대해서 알아본다.
%
% - High Bias: 너무나 단순화된 모델로 underfit
% - High Variance: 너무나 복잡화된 모델로 overfit
%
% ## 2.1. Learning curves
%
% `learningCurve.m`: Generates the train and cross validation set errors needed to plot a learning curve
%
% $$J_{train}(\theta) = \dfrac{1}{2m} \bigg[ \sum_{i=1}^{m} \left( h_\theta (x^{(i)}) - y^{(i)}  \right)^2 \bigg] $$

% %%
% Number of training examples
m = size(X, 1);
mval = size(Xval, 1);
% You need to return these values correctly
error_train = zeros(m, 1);
error_val   = zeros(m, 1);

% ====================== YOUR CODE HERE ======================
% Instructions: Fill in this function to return training errors in 
%               error_train and the cross validation errors in error_val. 
%               i.e., error_train(i) and 
%               error_val(i) should give you the errors
%               obtained after training on i examples.
%
% Note: You should evaluate the training error on the first i training
%       examples (i.e., X(1:i, :) and y(1:i)).
%
%       For the cross-validation error, you should instead evaluate on
%       the _entire_ cross validation set (Xval and yval).
%
% Note: If you are using your cost function (linearRegCostFunction)
%       to compute the training and cross validation error, you should 
%       call the function with the lambda argument set to 0. 
%       Do note that you will still need to use lambda when running
%       the training to obtain the theta parameters.
%
% Hint: You can loop over the examples with the following:
%
%       for i = 1:m
%           % Compute train/cross validation errors using training examples 
%           % X(1:i, :) and y(1:i), storing the result in 
%           % error_train(i) and error_val(i)
%           ....
%           
%       end
%

% ---------------------- Sample Solution ----------------------

lambda = 0;
for i = 1:m,
    Xsample = X(1:i, :);
    ysample = y(1:i);
    
    [theta] = trainLinearReg([ones(i, 1) Xsample], ysample, lambda);
    [error_train(i), _] = linearRegCostFunction([ones(i, 1) Xsample], ysample, theta, lambda);
    [error_val(i), _] = linearRegCostFunction([ones(mval, 1) Xval], yval, theta, lambda);
    
    

end
% Out:
% ...
%     fmincg at line 102 column 12
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
% ...

% %%
linearRegCostFunction([ones(m, 1) X], y, theta, 1)
% Out:
% ans =  22.380

% %%
%% =========== Part 5: Learning Curve for Linear Regression =============
%  Next, you should implement the learningCurve function. {
%
%  Write Up Note: Since the model is underfitting the data, we expect to
%                 see a graph with "high bias" -- Figure 3 in ex5.pdf 
%

lambda = 0;
[error_train, error_val] = ...
    learningCurve([ones(m, 1) X], y, ...
                  [ones(size(Xval, 1), 1) Xval], yval, ...
                  lambda);

plot(1:m, error_train, 1:m, error_val);
title('Learning curve for linear regression')
legend('Train', 'Cross Validation')
xlabel('Number of training examples')
ylabel('Error')
axis([0 13 0 150])

fprintf('# Training Examples\tTrain Error\tCross Validation Error\n');
for i = 1:m
    fprintf('  \t%d\t\t%f\t%f\n', i, error_train(i), error_val(i));
end
% Out:
% ...
%     fmincg at line 102 column 12
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
% ...

% %% [markdown]
% ### 주의점 및 결과
%
% - Training 할때는 $\lambda$를 주어서 학습하지만, 오차를 계산할 때는 더이상의 Regularization이 필요 없으므로 $\lambda = 0$ 으로 고정
%
% 위의 결과를 통해 모델이 너무 단순하다는 high-bias 문제 라는 것을 진달 할 수 있다.
%
% 따라서 데이터의 수를 늘리는 것이 아닌 차수를 늘리는 방향으로 진행
%
% ---

% %% [markdown]
% # 3. Polynomial regression
%
% `polyFeatures.m`
%
% $$
% \begin{align}
% h_{\theta}(x)
% &= \theta_0 + \theta_1 \times (\text{waterLevel}) +  \theta_2 \times (\text{waterLevel})^2 + \cdots + \theta_p \times (\text{waterLevel})^p \\
% &= \theta_0 + \theta_1 x_1 + \theta_2 x_2 + \cdots + + \theta_p x_p
% \end{align}
% $$

% %%
for i=1:8,
    X .^ i
end
% Out:
% ans =
%
%   -15.9368
%   -29.1530
%    36.1895
%    37.4922
%   -48.0588
%    -8.9415
%    15.3078
%   -34.7063
%     1.3892
%   -44.3838
%     7.0135
%    22.7627
%
% ans =
%
%     253.9803
%     849.8962
%    1309.6834
%    1405.6641
%    2309.6511
%      79.9497
%     234.3285
%    1204.5249
%       1.9297
%    1969.9181
%      49.1892
%     518.1427
%
% ans =
%
%     -4047.62197
%    -24777.00617
%     47396.85217
%     52701.42217
%   -110999.12775
%      -714.86661
%      3587.05250
%    -41804.56089
%         2.68072
%    -87432.37359
%       344.98864
%     11794.35306
%
% ans =
%
%      64505.97238
%     722323.54608
%    1715270.68630
%    1975891.59278
%    5334488.14992
%       6391.94974
%      54909.85676
%    1450880.20236
%          3.72393
%    3880577.47268
%       2419.57852
%     268471.89734
%
% ans =
%
%     -1028016.07993
%    -21057883.32712
%     62074871.90963
%     74080497.74413
%   -256369256.21386
%       -57153.34976
%       840548.71481
% ...

% %% [markdown]
% ## 3.1. Learning Polnomial Regression

% %%
%% =========== Part 6: Feature Mapping for Polynomial Regression =============
%  One solution to this is to use polynomial regression. You should now
%  complete polyFeatures to map each example into its powers
%

p = 8;

% Map X onto Polynomial Features and Normalize
X_poly = polyFeatures(X, p);
[X_poly, mu, sigma] = featureNormalize(X_poly);  % Normalize
X_poly = [ones(m, 1), X_poly];                   % Add Ones

% %%
% Map X_poly_test and normalize (using mu and sigma)
X_poly_test = polyFeatures(Xtest, p);
X_poly_test = bsxfun(@minus, X_poly_test, mu);
X_poly_test = bsxfun(@rdivide, X_poly_test, sigma);
X_poly_test = [ones(size(X_poly_test, 1), 1), X_poly_test];         % Add Ones

% Map X_poly_val and normalize (using mu and sigma)
X_poly_val = polyFeatures(Xval, p);
X_poly_val = bsxfun(@minus, X_poly_val, mu);
X_poly_val = bsxfun(@rdivide, X_poly_val, sigma);
X_poly_val = [ones(size(X_poly_val, 1), 1), X_poly_val];           % Add Ones

fprintf('Normalized Training Example 1:\n');
fprintf('  %f  \n', X_poly(1, :));
% Out:
% Normalized Training Example 1:
%   1.000000
%   -0.362141
%   -0.755087
%   0.182226
%   -0.706190
%   0.306618
%   -0.590878
%   0.344516
%   -0.508481

% %%
%% =========== Part 7: Learning Curve for Polynomial Regression =============
%  Now, you will get to experiment with polynomial regression with multiple
%  values of lambda. The code below runs polynomial regression with 
%  lambda = 0. You should try running the code with different values of
%  lambda to see how the fit and learning curve change.
%

lambda = 0;
[theta] = trainLinearReg(X_poly, y, lambda);

% Plot training data and fit
plot(X, y, 'rx', 'MarkerSize', 10, 'LineWidth', 1.5);
plotFit(min(X), max(X), mu, sigma, theta, p);
xlabel('Change in water level (x)');
ylabel('Water flowing out of the dam (y)');
title (sprintf('Polynomial Regression Fit (lambda = %f)', lambda));
% Out:
% Iteration   200 | Cost: 1.071169e-01

% %%
[error_train, error_val] = ...
    learningCurve(X_poly, y, X_poly_val, yval, lambda);
    
plot(1:m, error_train, 1:m, error_val);

title(sprintf('Polynomial Regression Learning Curve (lambda = %f)', lambda));
xlabel('Number of training examples')
ylabel('Error')
axis([0 13 0 100])
legend('Train', 'Cross Validation')

fprintf('Polynomial Regression (lambda = %f)\n\n', lambda);
fprintf('# Training Examples\tTrain Error\tCross Validation Error\n');
for i = 1:m
    fprintf('  \t%d\t\t%f\t%f\n', i, error_train(i), error_val(i));
end
% Out:
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
% ...

% %% [markdown]
% ## 3.2. Optional (ungraded) exercise: Adjusting the regularization parameter
%
% 앞서 발생한 overfitting 문제를 해결하기 위해 regularization을 적용

% %%
lambda = 1;
[theta] = trainLinearReg(X_poly, y, lambda);

% Plot training data and fit
plot(X, y, 'rx', 'MarkerSize', 10, 'LineWidth', 1.5);
plotFit(min(X), max(X), mu, sigma, theta, p);
xlabel('Change in water level (x)');
ylabel('Water flowing out of the dam (y)');
title (sprintf('Polynomial Regression Fit (lambda = %f)', lambda));
% Out:
% Iteration    59 | Cost: 7.268148e+00

% %%
[error_train, error_val] = ...
    learningCurve(X_poly, y, X_poly_val, yval, lambda);
    
plot(1:m, error_train, 1:m, error_val);

title(sprintf('Polynomial Regression Learning Curve (lambda = %f)', lambda));
xlabel('Number of training examples')
ylabel('Error')
axis([0 13 0 100])
legend('Train', 'Cross Validation')

fprintf('Polynomial Regression (lambda = %f)\n\n', lambda);
fprintf('# Training Examples\tTrain Error\tCross Validation Error\n');
for i = 1:m
    fprintf('  \t%d\t\t%f\t%f\n', i, error_train(i), error_val(i));
end
% Out:
% ...
%     fmincg at line 102 column 12
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
%     trainLinearReg at line 19 column 7
%     learningCurve at line 61 column 13
% ...
%     fmincg at line 124 column 8
% ...

% %%
lambda = 100;
[theta] = trainLinearReg(X_poly, y, lambda);

% Plot training data and fit
plot(X, y, 'rx', 'MarkerSize', 10, 'LineWidth', 1.5);
plotFit(min(X), max(X), mu, sigma, theta, p);
xlabel('Change in water level (x)');
ylabel('Water flowing out of the dam (y)');
title (sprintf('Polynomial Regression Fit (lambda = %f)', lambda));
% Out:
% Iteration    21 | Cost: 6.673316e+01

% %% [markdown]
% ## 3.3. Selecting λ using a cross validation set
%
% `validationCurve.m`
%
% $\lambda$는 결과에 큰 영향을 미치는 parameter로 validation 데이터를 사용하여 적절한 $\lambda$ 를 탐색해본다.

% %%
% =========== Part 8: Validation for Selecting Lambda =============
%  You will now implement validationCurve to test various values of 
%  lambda on a validation set. You will then use this to select the
%  "best" lambda value.
%

[lambda_vec, error_train, error_val] = ...
    validationCurve(X_poly, y, X_poly_val, yval);

close all;
plot(lambda_vec, error_train, lambda_vec, error_val);
legend('Train', 'Cross Validation');
xlabel('lambda');
ylabel('Error');

fprintf('lambda\t\tTrain Error\tValidation Error\n');
for i = 1:length(lambda_vec)
	fprintf(' %f\t%f\t%f\n', ...
            lambda_vec(i), error_train(i), error_val(i));
end
% Out:
% Iteration   200 | Cost: 1.071169e-01
% Iteration   200 | Cost: 1.880281e-01
% Iteration   200 | Cost: 2.507153e-01
% Iteration   200 | Cost: 3.850794e-01
% Iteration   200 | Cost: 6.692749e-01
% Iteration   134 | Cost: 1.443470e+00
% Iteration   129 | Cost: 3.101591e+00
% Iteration    59 | Cost: 7.268148e+00
% Iteration    34 | Cost: 1.586769e+01
% Iteration    25 | Cost: 3.337220e+01
% lambda		Train Error	Validation Error
%  0.000000	0.107117	9.809678
%  0.001000	0.155319	16.463263
%  0.003000	0.178840	17.806631
%  0.010000	0.222281	17.068863
%  0.030000	0.281867	12.828882
%  0.100000	0.459318	7.587014
%  0.300000	0.921760	4.636833
%  1.000000	2.076188	4.260625
%  3.000000	4.901351	3.822907
%  10.000000	16.092213	9.945509

% %% [markdown]
% 위의 validation 곡선으로 보아 3 근처의 값이 적절해 보인다.

% %% [markdown]
% ## 3.4. Optional (ungraded) exercise: Computing test set error

% %% [markdown]
% ## 3.5. Optional (ungraded) exercise: Plotting learning curves with randomly selected examples
